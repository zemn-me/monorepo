# %%
from sympy import Quaternion, solve, symbols, Eq

centre = Quaternion(0, *symbols('c_i c_j c_k'))

# vector from centre upward
up = Quaternion(0, *symbols('u_i u_j u_k'))

forward = Quaternion(0, *symbols('fw_i fw_j fw_k'))

r_w, r_i, r_j, r_k = symbols('r_w r_i r_j r_k')

rotation = Quaternion(r_w, r_i, r_j, r_k)

look_at = Quaternion(0, *symbols('la_i la_j la_k'))

centre_does_not_rotate = Eq(centre * rotation, centre)

forward_will_look_at = Eq(
	(forward * rotation).normalize(),
	(centre - look_at).normalize()
)

up_will_still_be_up = Eq(
    (up * rotation),
	up
)

solve(
    [
		centre_does_not_rotate,
		forward_will_look_at,
		up_will_still_be_up
	], [
        rotation
	]
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/expr.py:4035, in _mag(x)
#    4034 try:
# -> 4035     mag_first_dig = int(ceil(log10(xpos)))
#    4036 except (ValueError, OverflowError):
#
# ValueError: cannot convert float NaN to integer
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 28
#      18 forward_will_look_at = Eq(
#      19 	(forward * rotation).normalize(),
#      20 	(centre - look_at).normalize()
#      21 )
#      23 up_will_still_be_up = Eq(
#      24     (up * rotation),
#      25 	up
#      26 )
# ---> 28 solve(
#      29     [
#      30 		centre_does_not_rotate,
#      31 		forward_will_look_at,
#      32 		up_will_still_be_up
#      33 	], [
#      34         rotation
#      35 	]
#      36 )
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/solvers/solvers.py:1072, in solve(f, *symbols, **flags)
#    1070         ok = True
#    1071     else:
# -> 1072         if fi.is_constant():
#    1073             ok = True
#    1074 if ok:
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/expr.py:666, in Expr.is_constant(self, *wrt, **flags)
#     664 except ZeroDivisionError:
#     665     b = None
# --> 666 if b is not None and b is not S.NaN and b.equals(a) is False:
#     667     return False
#     668 # try random real
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/expr.py:730, in Expr.equals(self, other, failing_expression)
#     724     return True
#     726 # they aren't the same so see if we can make the difference 0;
#     727 # don't worry about doing simplification steps one at a time
#     728 # because if the expression ever goes to 0 then the subsequent
#     729 # simplification steps that are done will be very fast.
# --> 730 diff = factor_terms(simplify(self - other), radical=True)
#     732 if not diff:
#     733     return True
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/simplify/simplify.py:596, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     589 kwargs = {
#     590     "ratio": kwargs.get('ratio', ratio),
#     591     "measure": kwargs.get('measure', measure),
#     592     "rational": kwargs.get('rational', rational),
#     593     "inverse": kwargs.get('inverse', inverse),
#     594     "doit": kwargs.get('doit', doit)}
#     595 # no routine for Expr needs to check for is_zero
# --> 596 if isinstance(expr, Expr) and expr.is_zero:
#     597     return S.Zero if not expr.is_Number else expr
#     599 _eval_simplify = getattr(expr, '_eval_simplify', None)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/assumptions.py:559, in _ask(fact, obj)
#     557 handler_i = handler_map.get(fact_i)
#     558 if handler_i is not None:
# --> 559     fact_i_value = handler_i(obj)
#     561 # If we get a new value for fact_i then we should update our knowledge
#     562 # of fact_i as well as any related facts that can be inferred using the
#     563 # inference rules connecting the fact_i and any other fact values that
#     564 # are already known.
#     565 if fact_i_value is not None:
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/add.py:856, in Add._eval_is_extended_negative(self)
#     854 def _eval_is_extended_negative(self):
#     855     if self.is_number:
# --> 856         return super()._eval_is_extended_negative()
#     857     c, a = self.as_coeff_Add()
#     858     if not c.is_zero:
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/expr.py:883, in Expr._eval_is_extended_negative(self)
#     882 def _eval_is_extended_negative(self):
# --> 883     return self._eval_is_extended_positive_negative(positive=False)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/expr.py:846, in Expr._eval_is_extended_positive_negative(self, positive)
#     843 if self.is_number:
#     844     # check to see that we can get a value
#     845     try:
# --> 846         n2 = self._eval_evalf(2)
#     847     # XXX: This shouldn't be caught here
#     848     # Catches ValueError: hypsum() failed to converge to the requested
#     849     # 34 bits of accuracy
#     850     except ValueError:
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/operations.py:422, in AssocOp._eval_evalf(self, prec)
#     420 args = []
#     421 for a in self.args:
# --> 422     newa = a._eval_evalf(prec)
#     423     if newa is None:
#     424         args.append(a)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/mul.py:757, in Mul._eval_evalf(self, prec)
#     755     rv = -AssocOp._eval_evalf(m, prec)
#     756 else:
# --> 757     mnew = m._eval_evalf(prec)
#     758     if mnew is not None:
#     759         m = mnew
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/operations.py:422, in AssocOp._eval_evalf(self, prec)
#     420 args = []
#     421 for a in self.args:
# --> 422     newa = a._eval_evalf(prec)
#     423     if newa is None:
#     424         args.append(a)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/algebras/quaternion.py:1032, in Quaternion._eval_evalf(self, prec)
#    1010 """Returns the floating point approximations (decimal numbers) of the quaternion.
#    1011
#    1012 Returns
#    (...)
#    1029
#    1030 """
#    1031 nprec = prec_to_dps(prec)
# -> 1032 return Quaternion(*[arg.evalf(n=nprec) for arg in self.args])
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/algebras/quaternion.py:1032, in <listcomp>(.0)
#    1010 """Returns the floating point approximations (decimal numbers) of the quaternion.
#    1011
#    1012 Returns
#    (...)
#    1029
#    1030 """
#    1031 nprec = prec_to_dps(prec)
# -> 1032 return Quaternion(*[arg.evalf(n=nprec) for arg in self.args])
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/evalf.py:1634, in EvalfMixin.evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1632 from .expr import _mag
#    1633 rv = self.evalf(2, subs, maxn, chop, strict, quad, verbose)
# -> 1634 m = _mag(rv)
#    1635 rv = rv.round(1 - m)
#    1636 return rv
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/expr.py:4037, in _mag(x)
#    4035     mag_first_dig = int(ceil(log10(xpos)))
#    4036 except (ValueError, OverflowError):
# -> 4037     mag_first_dig = int(ceil(Float(mpf_log(xpos._mpf_, 53))/log(10)))
#    4038 # check that we aren't off by 1
#    4039 if (xpos/10**mag_first_dig) >= 1:
#
# AttributeError: 'NaN' object has no attribute '_mpf_'
