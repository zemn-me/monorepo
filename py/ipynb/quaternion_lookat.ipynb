# %%
from sympy import Quaternion, solve, symbols, Eq

centre = Quaternion(0, *symbols('c_i c_j c_k', real=True))

# vector from centre upward
up = Quaternion(0, *symbols('u_i u_j u_k', real=True))

forward = Quaternion(0, *symbols('fw_i fw_j fw_k', real=True))

r_w, r_i, r_j, r_k = symbols('r_w r_i r_j r_k', real=True)

rotation = Quaternion(r_w, r_i, r_j, r_k)

look_at = Quaternion(0, *symbols('la_i la_j la_k', real=True))

centre_does_not_rotate = Eq(centre * rotation, centre)

forward_will_look_at = Eq(
	(forward * rotation).normalize(),
	(centre - look_at).normalize()
)

up_will_still_be_up = Eq(
    (up * rotation),
	up
)

solve(
    [
		centre_does_not_rotate,
		forward_will_look_at,
		up_will_still_be_up
	], [
        r_w, r_i, r_j, r_k
	]
)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[28], line 31
#      21 forward_will_look_at = Eq(
#      22 	(forward * rotation).normalize(),
#      23 	(centre - look_at).normalize()
#      24 )
#      26 up_will_still_be_up = Eq(
#      27     (up * rotation),
#      28 	up
#      29 )
# ---> 31 solve(
#      32     [
#      33 		centre_does_not_rotate,
#      34 		forward_will_look_at,
#      35 		up_will_still_be_up
#      36 	], [
#      37         r_w, r_i, r_j, r_k
#      38 	]
#      39 )
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/solvers/solvers.py:1172, in solve(f, *symbols, **flags)
#    1170         solution = _solve(f[0], *symbols, **flags)
#    1171 else:
# -> 1172     linear, solution = _solve_system(f, symbols, **flags)
#    1173 assert type(solution) is list
#    1174 assert not solution or type(solution[0]) is dict, solution
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/solvers/solvers.py:1801, in _solve_system(exprs, symbols, **flags)
#    1799 subsyms = sorted(subsyms, key = lambda x: sym_indices[x])
#    1800 flags['_split'] = False  # skip split step
# -> 1801 _linear, subsol = _solve_system(subexpr, subsyms, **flags)
#    1802 if linear:
#    1803     linear = linear and _linear
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/solvers/solvers.py:2028, in _solve_system(exprs, symbols, **flags)
#    2024     result = [r for r in result
#    2025         if not any(checksol(d, r, **flags) for d in dens)]
#    2027 if check and not linear:
# -> 2028     result = [r for r in result
#    2029         if not any(checksol(e, r, **flags) is False for e in exprs)]
#    2031 result = [r for r in result if r]
#    2032 return linear, result
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/solvers/solvers.py:2029, in <listcomp>(.0)
#    2024     result = [r for r in result
#    2025         if not any(checksol(d, r, **flags) for d in dens)]
#    2027 if check and not linear:
#    2028     result = [r for r in result
# -> 2029         if not any(checksol(e, r, **flags) is False for e in exprs)]
#    2031 result = [r for r in result if r]
#    2032 return linear, result
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/solvers/solvers.py:2029, in <genexpr>(.0)
#    2024     result = [r for r in result
#    2025         if not any(checksol(d, r, **flags) for d in dens)]
#    2027 if check and not linear:
#    2028     result = [r for r in result
# -> 2029         if not any(checksol(e, r, **flags) is False for e in exprs)]
#    2031 result = [r for r in result if r]
#    2032 return linear, result
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/solvers/solvers.py:299, in checksol(f, symbol, sol, **flags)
#     297 elif attempt == 1:
#     298     if not val.is_number:
# --> 299         if not val.is_constant(*list(sol.keys()), simplify=not minimal):
#     300             return False
#     301         # there are free symbols -- simple expansion might work
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/expr.py:673, in Expr.is_constant(self, *wrt, **flags)
#     671     return False
#     672 # try random complex
# --> 673 b = expr._random()
#     674 if b is not None and b is not S.NaN:
#     675     if b.equals(a) is False:
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/expr.py:493, in Expr._random(self, n, re_min, im_min, re_max, im_max)
#     490 reps = dict(list(zip(free, [random_complex_number(a, b, c, d, rational=True)
#     491                for zi in free])))
#     492 try:
# --> 493     nmag = abs(self.evalf(2, subs=reps))
#     494 except (ValueError, TypeError):
#     495     # if an out of range value resulted in evalf problems
#     496     # then return None -- XXX is there a way to know how to
#     497     # select a good random number for a given expression?
#     498     # e.g. when calculating n! negative values for n should not
#     499     # be used
#     500     return None
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/expr.py:194, in Expr.__abs__(self)
#     192 def __abs__(self) -> Expr:
#     193     from sympy.functions.elementary.complexes import Abs
# --> 194     return Abs(self)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/function.py:466, in Function.__new__(cls, *args, **options)
#     458     raise TypeError(temp % {
#     459         'name': cls,
#     460         'qual': 'exactly' if len(cls.nargs) == 1 else 'at least',
#     461         'args': min(cls.nargs),
#     462         'plural': 's'*(min(cls.nargs) != 1),
#     463         'given': n})
#     465 evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 466 result = super().__new__(cls, *args, **options)
#     467 if evaluate and isinstance(result, cls) and result.args:
#     468     _should_evalf = [cls._should_evalf(a) for a in result.args]
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/function.py:307, in Application.__new__(cls, *args, **options)
#     304     raise ValueError("Unknown options: %s" % options)
#     306 if evaluate:
# --> 307     evaluated = cls.eval(*args)
#     308     if evaluated is not None:
#     309         return evaluated
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/functions/elementary/complexes.py:550, in Abs.eval(cls, arg)
#     548         known.append(Pow(bnew, t.exp))
#     549 else:
# --> 550     tnew = cls(t)
#     551     if isinstance(tnew, cls):
#     552         unk.append(t)
#
#     [... skipping similar frames: __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (1 times)]
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/function.py:466, in Function.__new__(cls, *args, **options)
#     458     raise TypeError(temp % {
#     459         'name': cls,
#     460         'qual': 'exactly' if len(cls.nargs) == 1 else 'at least',
#     461         'args': min(cls.nargs),
#     462         'plural': 's'*(min(cls.nargs) != 1),
#     463         'given': n})
#     465 evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 466 result = super().__new__(cls, *args, **options)
#     467 if evaluate and isinstance(result, cls) and result.args:
#     468     _should_evalf = [cls._should_evalf(a) for a in result.args]
#
#     [... skipping similar frames: __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (1 times)]
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/function.py:307, in Application.__new__(cls, *args, **options)
#     304     raise ValueError("Unknown options: %s" % options)
#     306 if evaluate:
# --> 307     evaluated = cls.eval(*args)
#     308     if evaluated is not None:
#     309         return evaluated
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/functions/elementary/complexes.py:550, in Abs.eval(cls, arg)
#     548         known.append(Pow(bnew, t.exp))
#     549 else:
# --> 550     tnew = cls(t)
#     551     if isinstance(tnew, cls):
#     552         unk.append(t)
#
#     [... skipping similar frames: __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (354 times), Function.__new__ at line 466 (177 times), Application.__new__ at line 307 (177 times), Abs.eval at line 550 (176 times)]
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/functions/elementary/complexes.py:550, in Abs.eval(cls, arg)
#     548         known.append(Pow(bnew, t.exp))
#     549 else:
# --> 550     tnew = cls(t)
#     551     if isinstance(tnew, cls):
#     552         unk.append(t)
#
#     [... skipping similar frames: __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (1 times)]
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/function.py:466, in Function.__new__(cls, *args, **options)
#     458     raise TypeError(temp % {
#     459         'name': cls,
#     460         'qual': 'exactly' if len(cls.nargs) == 1 else 'at least',
#     461         'args': min(cls.nargs),
#     462         'plural': 's'*(min(cls.nargs) != 1),
#     463         'given': n})
#     465 evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 466 result = super().__new__(cls, *args, **options)
#     467 if evaluate and isinstance(result, cls) and result.args:
#     468     _should_evalf = [cls._should_evalf(a) for a in result.args]
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/function.py:307, in Application.__new__(cls, *args, **options)
#     304     raise ValueError("Unknown options: %s" % options)
#     306 if evaluate:
# --> 307     evaluated = cls.eval(*args)
#     308     if evaluated is not None:
#     309         return evaluated
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/functions/elementary/complexes.py:534, in Abs.eval(cls, arg)
#     531     raise TypeError("Bad argument type for Abs(): %s" % type(arg))
#     533 # handle what we can
# --> 534 arg = signsimp(arg, evaluate=False)
#     535 n, d = arg.as_numer_denom()
#     536 if d.free_symbols and not n.free_symbols:
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/simplify/simplify.py:405, in signsimp(expr, evaluate)
#     403     return expr
#     404 # get rid of an pre-existing unevaluation regarding sign
# --> 405 e = expr.replace(lambda x: x.is_Mul and -(-x) != x, lambda x: -(-x))
#     406 e = sub_post(sub_pre(e))
#     407 if not isinstance(e, (Expr, Relational)) or e.is_Atom:
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:1749, in Basic.replace(self, query, value, map, simultaneous, exact)
#    1746             expr = v
#    1747     return expr
# -> 1749 rv = walk(self, rec_replace)
#    1750 return (rv, mapping) if map else rv
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:1724, in Basic.replace.<locals>.walk(rv, F)
#    1722 if args is not None:
#    1723     if args:
# -> 1724         newargs = tuple([walk(a, F) for a in args])
#    1725         if args != newargs:
#    1726             rv = rv.func(*newargs)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:1724, in <listcomp>(.0)
#    1722 if args is not None:
#    1723     if args:
# -> 1724         newargs = tuple([walk(a, F) for a in args])
#    1725         if args != newargs:
#    1726             rv = rv.func(*newargs)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:1724, in Basic.replace.<locals>.walk(rv, F)
#    1722 if args is not None:
#    1723     if args:
# -> 1724         newargs = tuple([walk(a, F) for a in args])
#    1725         if args != newargs:
#    1726             rv = rv.func(*newargs)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:1724, in <listcomp>(.0)
#    1722 if args is not None:
#    1723     if args:
# -> 1724         newargs = tuple([walk(a, F) for a in args])
#    1725         if args != newargs:
#    1726             rv = rv.func(*newargs)
#
#     [... skipping similar frames: <listcomp> at line 1724 (1 times), Basic.replace.<locals>.walk at line 1724 (1 times)]
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:1724, in Basic.replace.<locals>.walk(rv, F)
#    1722 if args is not None:
#    1723     if args:
# -> 1724         newargs = tuple([walk(a, F) for a in args])
#    1725         if args != newargs:
#    1726             rv = rv.func(*newargs)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:1724, in <listcomp>(.0)
#    1722 if args is not None:
#    1723     if args:
# -> 1724         newargs = tuple([walk(a, F) for a in args])
#    1725         if args != newargs:
#    1726             rv = rv.func(*newargs)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:1734, in Basic.replace.<locals>.walk(rv, F)
#    1732                     if rv == e and e != newargs[i]:
#    1733                         return rv
# -> 1734     rv = F(rv)
#    1735 return rv
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:1740, in Basic.replace.<locals>.rec_replace(expr)
#    1739 def rec_replace(expr):
# -> 1740     result = _query(expr)
#    1741     if result or result == {}:
#    1742         v = _value(expr, result)
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/simplify/simplify.py:405, in signsimp.<locals>.<lambda>(x)
#     403     return expr
#     404 # get rid of an pre-existing unevaluation regarding sign
# --> 405 e = expr.replace(lambda x: x.is_Mul and -(-x) != x, lambda x: -(-x))
#     406 e = sub_post(sub_pre(e))
#     407 if not isinstance(e, (Expr, Relational)) or e.is_Atom:
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/mul.py:181, in Mul.__neg__(self)
#     180 def __neg__(self):
# --> 181     c, args = self.as_coeff_mul()
#     182     if args[0] is not S.ComplexInfinity:
#     183         c = -c
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/basic.py:501, in Basic.__eq__(self, other)
#     499     return False
#     500 a, b = self._hashable_content(), other._hashable_content()
# --> 501 if a != b:
#     502     return False
#     503 # check number *in* an expression
#
# File ~/code/monorepo/.venv/lib/python3.11/site-packages/sympy/core/numbers.py:1112, in Float.__eq__(self, other)
#    1110 if isinstance(other, float):
#    1111     other = Float(other)
# -> 1112 return Basic.__eq__(self, other)
#
# RecursionError: maximum recursion depth exceeded
